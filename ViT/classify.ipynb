# %% [markdown]
# <a href="https://colab.research.google.com/github/friedrichor/Diabetic-Retinopathy-Detection/blob/main/classify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/friedrichor/Diabetic-Retinopathy-Detection
# Out:
# Cloning into 'Diabetic-Retinopathy-Detection'...
# remote: Enumerating objects: 14044, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 14044 (delta 4), reused 20 (delta 4), pack-reused 14024
# Receiving objects: 100% (14044/14044), 3.71 GiB | 52.97 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# Checking out files: 100% (11283/11283), done.

# %% [markdown]
# # Vision Transformer

# %%
# !python Diabetic-Retinopathy-Detection/train.py --batch-size 64 --batch-size 50
# Out:
# device = cuda:0
# 5200 images were found in the dataset.
# 4160 images for training.
# 1040 images for validation.
# Using 2 dataloader workers every process
# _IncompatibleKeys(missing_keys=['head.weight', 'head.bias'], unexpected_keys=[])
# training head.weight
# training head.bias
# [train epoch 0] loss: 0.691, acc: 0.511: 100% 84/84 [00:42<00:00,  1.97it/s]
# [valid epoch 0] loss: 0.684, acc: 0.605: 100% 21/21 [00:11<00:00,  1.83it/s]
# [train epoch 1] loss: 0.679, acc: 0.601: 100% 84/84 [00:43<00:00,  1.93it/s]
# [valid epoch 1] loss: 0.672, acc: 0.655: 100% 21/21 [00:12<00:00,  1.74it/s]
# [train epoch 2] loss: 0.670, acc: 0.653: 100% 84/84 [00:43<00:00,  1.93it/s]
# [valid epoch 2] loss: 0.661, acc: 0.694: 100% 21/21 [00:11<00:00,  1.80it/s]
# [train epoch 3] loss: 0.663, acc: 0.642: 100% 84/84 [00:48<00:00,  1.72it/s]
# [valid epoch 3] loss: 0.653, acc: 0.692: 100% 21/21 [00:11<00:00,  1.86it/s]
# [train epoch 4] loss: 0.655, acc: 0.672: 100% 84/84 [00:41<00:00,  2.03it/s]
# ...

# %%
# !python Diabetic-Retinopathy-Detection/predict.py  --path_json 'class_indices.json'
# Out:
# device = cuda:0
# tensor(0.5009)
# class: 0-1          prob: 0.499
# class: 2-3          prob: 0.501
# tensor(0.6226)
# class: 0-1          prob: 0.623
# class: 2-3          prob: 0.377
# tensor(0.6356)
# class: 0-1          prob: 0.364
# class: 2-3          prob: 0.636
# tensor(0.5526)
# class: 0-1          prob: 0.447
# class: 2-3          prob: 0.553
# tensor(0.5561)
# class: 0-1          prob: 0.556
# class: 2-3          prob: 0.444
# tensor(0.7513)
# class: 0-1          prob: 0.249
# class: 2-3          prob: 0.751
# tensor(0.7934)
# class: 0-1          prob: 0.793
# class: 2-3          prob: 0.207
# tensor(0.5909)
# class: 0-1          prob: 0.409
# class: 2-3          prob: 0.591
# tensor(0.5191)
# class: 0-1          prob: 0.481
# class: 2-3          prob: 0.519
# tensor(0.7359)
# class: 0-1          prob: 0.264
# class: 2-3          prob: 0.736
# tensor(0.5972)
# class: 0-1          prob: 0.403
# class: 2-3          prob: 0.597
# tensor(0.6459)
# ...

# %% [markdown]
# # ConvNet

# %%
# !python Diabetic-Retinopathy-Detection/ConvNet/train.py
# Out:
# using cuda:0 device.
# 5200 images were found in the dataset.
# 4160 images for training.
# 1040 images for validation.
# Using 2 dataloader workers every process
# _IncompatibleKeys(missing_keys=['head.weight', 'head.bias'], unexpected_keys=[])
# Param groups = {
#   "decay": {
#     "params": [
#       "downsample_layers.0.0.weight",
#       "downsample_layers.1.1.weight",
#       "downsample_layers.2.1.weight",
#       "downsample_layers.3.1.weight",
#       "stages.0.0.dwconv.weight",
#       "stages.0.0.pwconv1.weight",
#       "stages.0.0.pwconv2.weight",
#       "stages.0.1.dwconv.weight",
#       "stages.0.1.pwconv1.weight",
#       "stages.0.1.pwconv2.weight",
#       "stages.0.2.dwconv.weight",
#       "stages.0.2.pwconv1.weight",
#       "stages.0.2.pwconv2.weight",
#       "stages.1.0.dwconv.weight",
#       "stages.1.0.pwconv1.weight",
#       "stages.1.0.pwconv2.weight",
#       "stages.1.1.dwconv.weight",
#       "stages.1.1.pwconv1.weight",
# ...

# %%
# !python Diabetic-Retinopathy-Detection/ConvNet/predict.py
# Out:
# using cuda:0 device.
# Traceback (most recent call last):
#   File "Diabetic-Retinopathy-Detection/ConvNet/predict.py", line 86, in <module>
#     main()
#   File "Diabetic-Retinopathy-Detection/ConvNet/predict.py", line 44, in main
#     model.load_state_dict(torch.load(model_weight_path, map_location=device))
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 1498, in load_state_dict
#     self.__class__.__name__, "\n\t".join(error_msgs)))
# RuntimeError: Error(s) in loading state_dict for ConvNeXt:
# 	size mismatch for head.weight: copying a param with shape torch.Size([2, 768]) from checkpoint, the shape in current model is torch.Size([5, 768]).
# 	size mismatch for head.bias: copying a param with shape torch.Size([2]) from checkpoint, the shape in current model is torch.Size([5]).

# %%
#export your model's weights for future use
from google.colab import files
files.download('./weights//best_model.pth')
